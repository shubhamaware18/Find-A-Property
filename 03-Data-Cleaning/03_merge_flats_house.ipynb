# %%
import numpy as np
import pandas as pd
import re

# %%
flats = pd.read_csv('/content/drive/MyDrive/House-Price/datasets/Processed/flats_cleaned.csv')
houses = pd.read_csv('/content/drive/MyDrive/House-Price/datasets/Processed/house_cleaned.csv')

# %%
df = pd.concat([flats, houses], ignore_index=True)

# %%
df = df.sample(df.shape[0], ignore_index=True)

# %%
df.head()
# Out:
#                                      property_name property_type  \
# 0                  2 BHK Flat in Sector 85 Gurgaon          flat
# 1  9 Bedroom House for sale in Sushant Lok Phase 3         house
# 2   9 Bedroom House for sale in Sector 23A Gurgaon         house
# 3                  3 BHK Flat in Sector 92 Gurgaon          flat
# 4          5 Bedroom House for sale in DLF Phase 1         house
#
#            society  price  price_per_sqft    area  \
# 0      ss the leaf    NaN          9677.0     NaN
# 1      independent   7.25         26852.0  2700.0
# 2      independent   5.50         13095.0  4200.0
# 3  sare green parc   0.85          6538.0  1300.0
# 4      independent   7.00         39265.0  1783.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 1772(164.62 sq.m.)Carpet a...        2         2
# 1                        Plot area 300(250.84 sq.m.)        9         9
# 2                       Plot area 4200(390.19 sq.m.)        9         9
# 3                 Built Up area: 1300 (120.77 sq.m.)        3         2
# 4                    Plot area 1782.72(165.62 sq.m.)        5         5
#
#   balcony                  additionalRoom  \
# 0      3+                      store room
# 1      3+  servant room,others,pooja room
# 2      3+             servant room,others
# 3       2                   not available
# 4       2                    servant room
#
#                                           address  floorNum      facing  \
# 0    Tower 1, Sector 85 Gurgaon, Gurgaon, Haryana       9.0        East
# 1           Sushant Lok Phase 3, Gurgaon, Haryana       2.0  North-East
# 2            Sector 23A Gurgaon, Gurgaon, Haryana       3.0       South
# 3  Sector 92, Sector 92 Gurgaon, Gurgaon, Haryana      20.0         NaN
# 4                   DLF Phase 1, Gurgaon, Haryana       3.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 1   0 to 1 Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
# 2  5 to 10 Year Old  ['HUDA Sector 23 Market', 'Palam triangle', 'P...
# 3         undefined  ['Huda city centre metro station', 'Iffco chow...
# 4   1 to 5 Year Old  ['Guru dronacharya metro station', 'Dlf phase ...
#
#                                          description  \
# 0  Looking for a 2 bhk property for sale in gurga...
# 1  Check out this 9 bhk house for sale in sushant...
# 2  Prime location with only 5 min walk to all bas...
# 3  Best in class property available at sector 92 ...
# 4  Spacious rooms, luxurious living of standard, ...
#
#                                       furnishDetails  \
# 0  ['10 Light', '4 AC', 'No Bed', 'No Chimney', '...
# 1  ['9 Wardrobe', '26 Fan', '1 Exhaust Fan', '12 ...
# 2  ['6 Wardrobe', '18 Fan', '1 Exhaust Fan', '1 M...
# 3                                                NaN
# 4  ['1 Wardrobe', '1 Fan', '1 Geyser', '1 Light',...
#
#                                             features  \
# 0  ['Centrally Air Conditioned', 'Water purifier'...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2                                                NaN
# 3                                                NaN
# 4                       ['Private Garden / Terrace']
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 3  ['Environment5 out of 5', 'Safety3 out of 5', ...
# 4  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.to_csv('gurgaon_properties.csv', index=False)
